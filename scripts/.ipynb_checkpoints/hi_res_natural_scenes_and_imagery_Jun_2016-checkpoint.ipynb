# %% [markdown]
# ### Experimental design for a natural scenes + imagery experiment

# %%
from glob import glob
from scipy.io import loadmat
from scipy import ndimage as ndi
import scipy.fftpack 
from skimage import data
from skimage.util import img_as_float
from skimage.filter import gabor_kernel
from PIL import Image
from object_parsing.src.image_objects import make_a_blank, put_text
import numpy as np
import string
from os import path
from experimental_design.src.experiments import make_design_matrix, fmri_experiment
from scipy.io import loadmat
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def print_exp_info(param_dict):
    
    X1,X2 = param_dict['STIMULUS_PIXELS'], param_dict['VIEWING_ANGLE']
    param_dict['PIXELS_PER_DEGREE'] = X1/X2

    

    X1,X2,X3,X4,X5 = map(lambda w: param_dict[w], ['PICS','TIME_PER_PIC', 'REPS_PER_PIC', 'FADE_IN_FRAMES', 'FADE_OUT_FRAMES'])
    param_dict['RUN_DURATION'] = ((X1*(X2))*X3 + X4+X5)/60.
    
    param_dict['TOTAL_SCAN_TIME'] = param_dict['RUN_DURATION']*param_dict['RUNS']*param_dict['REPS_PER_RUN']

    param_dict['UNIQUE_PICS'] = param_dict['PICS']*param_dict['RUNS']
    
    print 'pixels per deg. %0.3f' %(param_dict['PIXELS_PER_DEGREE'])
    print '%d unique images will be shown %d times per run' %(param_dict['PICS'],param_dict['REPS_PER_PIC'])
    print 'average run duration (min): %0.3f' %(param_dict['RUN_DURATION'])
    print 'total time across runs (min): %0.3f' %(param_dict['RUN_DURATION']*param_dict['RUNS'])
    print 'we have a total of %f minutes = %f hours of scan time' %(param_dict['TOTAL_SCAN_TIME'], param_dict['TOTAL_SCAN_TIME']/60.)
    print 'assuming non-overlapping images in each run, a total of %d unique images shown' %(param_dict['UNIQUE_PICS'])
    print 'given a TR of %0.3f, movie frame rate should be (Hz): %0.6f' %(param_dict['TR'], param_dict['FRAMES_PER_TR']/param_dict['TR'])
    
    return param_dict

# %% [markdown]
# ### Create training runs

# %% [markdown]
# #### training set parameters

# %%
train_param_dict = {}

train_param_dict['savedir'] = '/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/training_images/'

##image parameters
train_param_dict['STIMULUS_PIXELS'] = 768
train_param_dict['VIEWING_ANGLE'] = 22.1 ##edge-to-edge of 768pix stim
train_param_dict['PICS'] = 37 ##the number of images per run
train_param_dict['isi_luminance'] = 140
train_param_dict['CUE_POS'] = (0.5, 0.515)
train_param_dict['CUE_SIZE'] = 0.017


##timing parameters
train_param_dict['FRAMES_PER_TR'] = 1. ##number of frames per tr (s)
train_param_dict['TR'] = 1.5
train_param_dict['REPS_PER_PIC'] = 2      ## number of times each image is shown in a run.
train_param_dict['ISI_LAM'] = 0.4         ## the average of poisson dist. for sampling number of isi frames after each image


train_param_dict['FADE_IN_FRAMES'] = 10   ## number of TRs for fading in. should be equal to expected length of HRF
train_param_dict['FADE_OUT_FRAMES'] = 10  ## number of TRs for fading out. should be equal to expected length of HRF
train_param_dict['RUNS'] = 38              ## number of runs


train_param_dict['REPS_PER_RUN'] = 2              ## number of times each run will be shown

TR,frames_per_tr,isi = train_param_dict['TR'],train_param_dict['FRAMES_PER_TR'],train_param_dict['ISI_LAM']
train_param_dict['TIME_PER_PIC'] = (TR*(1./frames_per_tr))+(1+isi)*TR  ##cue+showtime+isi

# %%
print 'TRAINING SET PARAMETERS'
train_param_dict=print_exp_info(train_param_dict)
# Out:
# TRAINING SET PARAMETERS
# pixels per deg. 34.751
# 37 unique images will be shown 2 times per run
# average run duration (min): 4.773
# total time across runs (min): 181.387
# we have a total of 362.773333 minutes = 6.046222 hours of scan time
# assuming non-overlapping images in each run, a total of 1406 unique images shown
# given a TR of 1.500, movie frame rate should be (Hz): 0.666667

# %% [markdown]
# #### blank, cue, etc.

# %%
##isi screen
savedir = train_param_dict['savedir']
blank_lum = train_param_dict['isi_luminance']
stim_pix = train_param_dict['STIMULUS_PIXELS']
blank_screen_name = path.join(savedir,'blank_screen_%0.3d.png' %(blank_lum)) 

blank_screen = make_a_blank(stim_pix,blank_lum,'L')
blank_screen.save(blank_screen_name)

# %% [markdown]
# #### resize/save training images

# %%
##create picture names
dx = loadmat('/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/stimDxTrnVal.mat')['stimDxTrn'][0]
pic_names = map(lambda x: '%0.6d.png' % (x), dx)[:train_param_dict['UNIQUE_PICS']]
print len(pic_names)
print pic_names[:10]
# Out:
# 1406
# ['003037.png', '000188.png', '002327.png', '003427.png', '000502.png', '002386.png', '003741.png', '002777.png', '000717.png', '003264.png']

# %%
##resize/save

# stim_pix = train_param_dict['STIMULUS_PIXELS']
# savedir = train_param_dict['savedir']
# pic_loc = '/Users/tnaselar/Data/Pictures/LotusHill2/pictures'
# for pn in pic_names:
#     img = Image.open(path.join(pic_loc,pn)).resize((stim_pix, stim_pix))
#     pn = path.basename(pn)
#     img.save(path.join(savedir,pn),'png')
#     print 'resized/saved %s' %(pn)
# Out:
# resized/saved 003037.png
# resized/saved 000188.png
# resized/saved 002327.png
# resized/saved 003427.png
# resized/saved 000502.png
# resized/saved 002386.png
# resized/saved 003741.png
# resized/saved 002777.png
# resized/saved 000717.png
# resized/saved 003264.png
# resized/saved 000683.png
# resized/saved 001055.png
# resized/saved 000761.png
# resized/saved 003419.png
# resized/saved 003070.png
# resized/saved 000294.png
# resized/saved 002395.png
# resized/saved 000817.png
# resized/saved 000769.png
# resized/saved 002480.png
# resized/saved 000816.png
# resized/saved 003110.png
# resized/saved 003949.png
# resized/saved 000181.png
# resized/saved 002916.png
# resized/saved 000202.png
# resized/saved 000494.png
# resized/saved 000706.png
# resized/saved 003133.png
# resized/saved 000750.png
# resized/saved 003141.png
# resized/saved 003207.png
# resized/saved 003973.png
# resized/saved 002650.png
# resized/saved 003183.png
# resized/saved 002377.png
# resized/saved 003261.png
# resized/saved 002632.png
# resized/saved 003626.png
# resized/saved 002593.png
# resized/saved 000019.png
# resized/saved 003413.png
# resized/saved 002610.png
# resized/saved 002477.png
# resized/saved 002053.png
# resized/saved 003535.png
# resized/saved 003652.png
# resized/saved 001771.png
# resized/saved 003985.png
# resized/saved 002483.png
# resized/saved 002743.png
# resized/saved 002884.png
# resized/saved 003573.png
# resized/saved 002389.png
# resized/saved 003620.png
# resized/saved 003672.png
# resized/saved 002567.png
# resized/saved 003204.png
# resized/saved 000559.png
# resized/saved 002543.png
# resized/saved 000154.png
# resized/saved 004023.png
# resized/saved 003330.png
# resized/saved 000587.png
# resized/saved 003331.png
# resized/saved 003547.png
# resized/saved 002742.png
# resized/saved 002736.png
# resized/saved 000805.png
# resized/saved 003249.png
# resized/saved 002341.png
# resized/saved 000162.png
# resized/saved 004175.png
# resized/saved 003346.png
# resized/saved 003262.png
# resized/saved 000191.png
# resized/saved 000804.png
# resized/saved 003053.png
# resized/saved 003339.png
# resized/saved 003663.png
# resized/saved 000703.png
# resized/saved 003704.png
# resized/saved 001819.png
# resized/saved 000855.png
# resized/saved 000742.png
# resized/saved 000030.png
# resized/saved 002643.png
# resized/saved 003356.png
# resized/saved 002773.png
# resized/saved 000117.png
# resized/saved 000593.png
# resized/saved 003062.png
# resized/saved 002227.png
# resized/saved 004053.png
# resized/saved 002312.png
# resized/saved 003661.png
# resized/saved 002515.png
# resized/saved 000676.png
# resized/saved 003480.png
# resized/saved 000503.png
# resized/saved 001577.png
# resized/saved 001848.png
# resized/saved 000200.png
# resized/saved 003018.png
# resized/saved 003380.png
# resized/saved 002573.png
# resized/saved 002437.png
# resized/saved 000160.png
# resized/saved 003089.png
# resized/saved 000708.png
# resized/saved 002710.png
# resized/saved 000312.png
# resized/saved 000685.png
# resized/saved 002423.png
# resized/saved 003926.png
# resized/saved 002409.png
# resized/saved 002675.png
# resized/saved 000798.png
# resized/saved 001674.png
# resized/saved 000819.png
# resized/saved 000573.png
# resized/saved 003436.png
# resized/saved 000031.png
# resized/saved 003155.png
# resized/saved 003845.png
# resized/saved 000757.png
# resized/saved 002618.png
# resized/saved 003774.png
# resized/saved 003041.png
# resized/saved 000212.png
# resized/saved 000479.png
# resized/saved 003768.png
# resized/saved 000610.png
# resized/saved 000469.png
# resized/saved 000741.png
# resized/saved 003168.png
# resized/saved 003181.png
# resized/saved 002042.png
# resized/saved 003789.png
# resized/saved 002774.png
# resized/saved 002577.png
# resized/saved 003347.png
# resized/saved 003753.png
# resized/saved 000810.png
# resized/saved 003333.png
# resized/saved 003307.png
# resized/saved 000260.png
# resized/saved 000497.png
# resized/saved 003078.png
# resized/saved 000305.png
# resized/saved 001836.png
# resized/saved 003153.png
# resized/saved 001626.png
# resized/saved 003711.png
# resized/saved 002657.png
# resized/saved 000447.png
# resized/saved 003165.png
# resized/saved 001632.png
# resized/saved 003247.png
# resized/saved 002597.png
# resized/saved 003519.png
# resized/saved 000700.png
# resized/saved 002085.png
# resized/saved 004236.png
# resized/saved 000826.png
# resized/saved 002679.png
# resized/saved 000242.png
# resized/saved 000291.png
# resized/saved 004156.png
# resized/saved 002590.png
# resized/saved 000393.png
# resized/saved 001821.png
# resized/saved 003152.png
# resized/saved 000499.png
# resized/saved 000718.png
# resized/saved 002303.png
# resized/saved 003633.png
# resized/saved 002792.png
# resized/saved 000298.png
# resized/saved 002474.png
# resized/saved 002616.png
# resized/saved 003232.png
# resized/saved 002547.png
# resized/saved 002674.png
# resized/saved 003898.png
# resized/saved 002404.png
# resized/saved 001905.png
# resized/saved 000237.png
# resized/saved 002600.png
# resized/saved 003514.png
# resized/saved 003738.png
# resized/saved 000546.png
# resized/saved 000719.png
# resized/saved 002691.png
# resized/saved 003865.png
# resized/saved 000179.png
# resized/saved 000022.png
# resized/saved 002529.png
# resized/saved 000705.png
# resized/saved 003222.png
# resized/saved 000522.png
# resized/saved 003103.png
# resized/saved 002899.png
# resized/saved 003392.png
# resized/saved 002417.png
# resized/saved 003649.png
# resized/saved 003424.png
# resized/saved 001927.png
# resized/saved 004145.png
# resized/saved 003172.png
# resized/saved 003540.png
# resized/saved 003272.png
# resized/saved 004233.png
# resized/saved 002469.png
# resized/saved 000122.png
# resized/saved 002911.png
# resized/saved 000013.png
# resized/saved 004110.png
# resized/saved 002589.png
# resized/saved 001128.png
# resized/saved 000583.png
# resized/saved 000749.png
# resized/saved 000916.png
# resized/saved 003190.png
# resized/saved 000444.png
# resized/saved 002694.png
# resized/saved 000235.png
# resized/saved 003639.png
# resized/saved 003201.png
# resized/saved 003310.png
# resized/saved 001928.png
# resized/saved 002665.png
# resized/saved 004190.png
# resized/saved 000770.png
# resized/saved 000562.png
# resized/saved 000933.png
# resized/saved 000713.png
# resized/saved 003763.png
# resized/saved 000811.png
# resized/saved 000480.png
# resized/saved 002788.png
# resized/saved 000164.png
# resized/saved 002760.png
# resized/saved 004139.png
# resized/saved 002872.png
# resized/saved 004186.png
# resized/saved 003391.png
# resized/saved 003319.png
# resized/saved 000161.png
# resized/saved 004098.png
# resized/saved 003277.png
# resized/saved 001925.png
# resized/saved 000216.png
# resized/saved 001904.png
# resized/saved 000207.png
# resized/saved 000406.png
# resized/saved 004058.png
# resized/saved 004026.png
# resized/saved 002425.png
# resized/saved 002519.png
# resized/saved 002894.png
# resized/saved 000714.png
# resized/saved 004168.png
# resized/saved 000158.png
# resized/saved 002900.png
# resized/saved 001917.png
# resized/saved 001583.png
# resized/saved 000183.png
# resized/saved 001584.png
# resized/saved 001572.png
# resized/saved 002360.png
# resized/saved 000756.png
# resized/saved 000584.png
# resized/saved 003208.png
# resized/saved 002697.png
# resized/saved 003306.png
# resized/saved 000633.png
# resized/saved 003697.png
# resized/saved 001127.png
# resized/saved 003571.png
# resized/saved 002746.png
# resized/saved 003552.png
# resized/saved 003358.png
# resized/saved 001606.png
# resized/saved 002300.png
# resized/saved 003180.png
# resized/saved 000464.png
# resized/saved 003905.png
# resized/saved 000171.png
# resized/saved 000151.png
# resized/saved 003494.png
# resized/saved 004064.png
# resized/saved 001964.png
# resized/saved 002670.png
# resized/saved 003394.png
# resized/saved 004193.png
# resized/saved 004148.png
# resized/saved 004001.png
# resized/saved 003568.png
# resized/saved 003596.png
# resized/saved 000716.png
# resized/saved 000244.png
# resized/saved 000109.png
# resized/saved 002324.png
# resized/saved 003383.png
# resized/saved 003486.png
# resized/saved 000570.png
# resized/saved 003082.png
# resized/saved 000185.png
# resized/saved 000239.png
# resized/saved 003287.png
# resized/saved 000255.png
# resized/saved 003387.png
# resized/saved 000032.png
# resized/saved 002387.png
# resized/saved 002496.png
# resized/saved 000459.png
# resized/saved 004078.png
# resized/saved 000281.png
# resized/saved 002226.png
# resized/saved 003879.png
# resized/saved 003040.png
# resized/saved 000277.png
# resized/saved 003417.png
# resized/saved 000943.png
# resized/saved 003510.png
# resized/saved 003202.png
# resized/saved 001645.png
# resized/saved 000005.png
# resized/saved 003717.png
# resized/saved 003096.png
# resized/saved 001938.png
# resized/saved 003384.png
# resized/saved 003643.png
# resized/saved 000220.png
# resized/saved 002778.png
# resized/saved 003683.png
# resized/saved 002628.png
# resized/saved 001327.png
# resized/saved 003430.png
# resized/saved 003766.png
# resized/saved 002526.png
# resized/saved 004147.png
# resized/saved 000371.png
# resized/saved 003614.png
# resized/saved 002453.png
# resized/saved 002428.png
# resized/saved 000760.png
# resized/saved 003675.png
# resized/saved 004157.png
# resized/saved 000029.png
# resized/saved 002364.png
# resized/saved 002904.png
# resized/saved 000130.png
# resized/saved 000135.png
# resized/saved 000790.png
# resized/saved 002592.png
# resized/saved 002928.png
# resized/saved 000726.png
# resized/saved 003359.png
# resized/saved 003069.png
# resized/saved 000684.png
# resized/saved 002325.png
# resized/saved 004132.png
# resized/saved 003077.png
# resized/saved 000009.png
# resized/saved 001567.png
# resized/saved 003407.png
# resized/saved 000205.png
# resized/saved 003771.png
# resized/saved 002793.png
# resized/saved 002521.png
# resized/saved 002664.png
# resized/saved 003120.png
# resized/saved 003422.png
# resized/saved 002639.png
# resized/saved 003176.png
# resized/saved 003467.png
# resized/saved 003444.png
# resized/saved 003126.png
# resized/saved 000229.png
# resized/saved 003836.png
# resized/saved 002702.png
# resized/saved 002508.png
# resized/saved 000194.png
# resized/saved 004165.png
# resized/saved 003317.png
# resized/saved 003462.png
# resized/saved 003623.png
# resized/saved 003508.png
# resized/saved 003471.png
# resized/saved 002542.png
# resized/saved 002581.png
# resized/saved 002446.png
# resized/saved 002361.png
# resized/saved 003352.png
# resized/saved 004207.png
# resized/saved 002459.png
# resized/saved 000247.png
# resized/saved 002438.png
# resized/saved 002418.png
# resized/saved 001858.png
# resized/saved 003282.png
# resized/saved 002725.png
# resized/saved 004185.png
# resized/saved 003621.png
# resized/saved 000152.png
# resized/saved 000266.png
# resized/saved 002687.png
# resized/saved 002749.png
# resized/saved 000514.png
# resized/saved 000253.png
# resized/saved 002667.png
# resized/saved 003769.png
# resized/saved 003602.png
# resized/saved 003970.png
# resized/saved 002441.png
# resized/saved 000812.png
# resized/saved 002680.png
# resized/saved 002830.png
# resized/saved 002449.png
# resized/saved 003327.png
# resized/saved 002430.png
# resized/saved 003209.png
# resized/saved 003574.png
# resized/saved 003838.png
# resized/saved 002974.png
# resized/saved 000100.png
# resized/saved 003048.png
# resized/saved 003556.png
# resized/saved 003517.png
# resized/saved 003411.png
# resized/saved 002646.png
# resized/saved 001554.png
# resized/saved 003258.png
# resized/saved 003758.png
# resized/saved 003452.png
# resized/saved 002305.png
# resized/saved 002351.png
# resized/saved 001969.png
# resized/saved 000427.png
# resized/saved 002383.png
# resized/saved 000138.png
# resized/saved 002828.png
# resized/saved 003459.png
# resized/saved 000024.png
# resized/saved 001767.png
# resized/saved 003990.png
# resized/saved 002323.png
# resized/saved 002484.png
# resized/saved 000236.png
# resized/saved 000754.png
# resized/saved 002847.png
# resized/saved 003885.png
# resized/saved 002671.png
# resized/saved 000003.png
# resized/saved 002546.png
# resized/saved 004125.png
# resized/saved 003528.png
# resized/saved 000131.png
# resized/saved 003785.png
# resized/saved 002684.png
# resized/saved 003557.png
# resized/saved 002326.png
# resized/saved 003127.png
# resized/saved 000214.png
# resized/saved 000585.png
# resized/saved 002685.png
# resized/saved 002431.png
# resized/saved 003270.png
# resized/saved 000735.png
# resized/saved 000710.png
# resized/saved 000773.png
# resized/saved 001806.png
# resized/saved 003734.png
# resized/saved 003726.png
# resized/saved 003149.png
# resized/saved 000787.png
# resized/saved 003088.png
# resized/saved 003163.png
# resized/saved 002913.png
# resized/saved 000631.png
# resized/saved 003521.png
# resized/saved 000947.png
# resized/saved 003166.png
# resized/saved 000606.png
# resized/saved 000528.png
# resized/saved 002320.png
# resized/saved 002309.png
# resized/saved 003298.png
# resized/saved 003354.png
# resized/saved 000733.png
# resized/saved 002588.png
# resized/saved 001611.png
# resized/saved 003752.png
# resized/saved 002525.png
# resized/saved 003093.png
# resized/saved 003043.png
# resized/saved 002678.png
# resized/saved 003192.png
# resized/saved 003645.png
# resized/saved 000720.png
# resized/saved 003265.png
# resized/saved 002494.png
# resized/saved 003185.png
# resized/saved 003488.png
# resized/saved 003458.png
# resized/saved 003036.png
# resized/saved 002635.png
# resized/saved 002511.png
# resized/saved 003116.png
# resized/saved 002396.png
# resized/saved 003314.png
# resized/saved 000234.png
# resized/saved 003035.png
# resized/saved 000286.png
# resized/saved 003449.png
# resized/saved 001655.png
# resized/saved 002734.png
# resized/saved 002031.png
# resized/saved 002313.png
# resized/saved 003072.png
# resized/saved 003154.png
# resized/saved 000157.png
# resized/saved 000727.png
# resized/saved 001911.png
# resized/saved 003837.png
# resized/saved 002373.png
# resized/saved 000664.png
# resized/saved 003046.png
# resized/saved 000786.png
# resized/saved 002881.png
# resized/saved 003657.png
# resized/saved 002460.png
# resized/saved 001678.png
# resized/saved 000127.png
# resized/saved 001793.png
# resized/saved 000671.png
# resized/saved 001872.png
# resized/saved 003063.png
# resized/saved 003476.png
# resized/saved 001875.png
# resized/saved 002686.png
# resized/saved 003405.png
# resized/saved 003671.png
# resized/saved 003635.png
# resized/saved 000156.png
# resized/saved 000807.png
# resized/saved 003397.png
# resized/saved 001650.png
# resized/saved 000849.png
# resized/saved 003194.png
# resized/saved 000264.png
# resized/saved 004068.png
# resized/saved 004091.png
# resized/saved 002352.png
# resized/saved 004219.png
# resized/saved 000544.png
# resized/saved 000830.png
# resized/saved 000832.png
# resized/saved 002148.png
# resized/saved 003805.png
# resized/saved 002486.png
# resized/saved 002561.png
# resized/saved 003364.png
# resized/saved 002951.png
# resized/saved 002762.png
# resized/saved 003646.png
# resized/saved 001881.png
# resized/saved 000778.png
# resized/saved 000611.png
# resized/saved 002470.png
# resized/saved 002315.png
# resized/saved 002276.png
# resized/saved 000765.png
# resized/saved 004027.png
# resized/saved 003534.png
# resized/saved 000809.png
# resized/saved 002497.png
# resized/saved 001816.png
# resized/saved 002619.png
# resized/saved 000180.png
# resized/saved 000813.png
# resized/saved 003315.png
# resized/saved 000827.png
# resized/saved 002366.png
# resized/saved 000571.png
# resized/saved 003589.png
# resized/saved 003234.png
# resized/saved 002976.png
# resized/saved 003496.png
# resized/saved 000715.png
# resized/saved 000657.png
# resized/saved 000759.png
# resized/saved 000938.png
# resized/saved 000159.png
# resized/saved 000113.png
# resized/saved 000146.png
# resized/saved 004131.png
# resized/saved 001818.png
# resized/saved 002647.png
# resized/saved 000182.png
# resized/saved 002985.png
# resized/saved 000007.png
# resized/saved 002301.png
# resized/saved 000747.png
# resized/saved 000147.png
# resized/saved 000445.png
# resized/saved 000739.png
# resized/saved 000165.png
# resized/saved 000784.png
# resized/saved 001300.png
# resized/saved 003470.png
# resized/saved 002634.png
# resized/saved 003224.png
# resized/saved 002918.png
# resized/saved 003316.png
# resized/saved 001814.png
# resized/saved 003515.png
# resized/saved 000261.png
# resized/saved 003956.png
# resized/saved 003455.png
# resized/saved 000168.png
# resized/saved 002421.png
# resized/saved 000369.png
# resized/saved 000134.png
# resized/saved 004184.png
# resized/saved 000218.png
# resized/saved 003587.png
# resized/saved 003350.png
# resized/saved 000016.png
# resized/saved 001869.png
# resized/saved 002476.png
# resized/saved 002506.png
# resized/saved 002394.png
# resized/saved 003983.png
# resized/saved 000768.png
# resized/saved 003236.png
# resized/saved 002681.png
# resized/saved 003688.png
# resized/saved 001894.png
# resized/saved 000384.png
# resized/saved 003627.png
# resized/saved 000517.png
# resized/saved 003744.png
# resized/saved 003215.png
# resized/saved 000169.png
# resized/saved 003361.png
# resized/saved 002522.png
# resized/saved 002821.png
# resized/saved 003421.png
# resized/saved 003293.png
# resized/saved 000015.png
# resized/saved 002487.png
# resized/saved 003545.png
# resized/saved 000193.png
# resized/saved 003280.png
# resized/saved 000836.png
# resized/saved 000120.png
# resized/saved 004141.png
# resized/saved 001923.png
# resized/saved 003227.png
# resized/saved 002692.png
# resized/saved 003465.png
# resized/saved 000471.png
# resized/saved 003550.png
# resized/saved 003883.png
# resized/saved 000520.png
# resized/saved 002412.png
# resized/saved 003790.png
# resized/saved 000605.png
# resized/saved 003603.png
# resized/saved 003628.png
# resized/saved 002859.png
# resized/saved 000115.png
# resized/saved 000028.png
# resized/saved 003586.png
# resized/saved 003076.png
# resized/saved 003566.png
# resized/saved 000284.png
# resized/saved 002463.png
# resized/saved 001126.png
# resized/saved 000107.png
# resized/saved 003703.png
# resized/saved 003050.png
# resized/saved 004162.png
# resized/saved 003365.png
# resized/saved 000167.png
# resized/saved 002789.png
# resized/saved 003246.png
# resized/saved 000766.png
# resized/saved 003976.png
# resized/saved 000027.png
# resized/saved 002296.png
# resized/saved 003491.png
# resized/saved 000554.png
# resized/saved 000820.png
# resized/saved 003038.png
# resized/saved 001870.png
# resized/saved 003211.png
# resized/saved 002631.png
# resized/saved 002401.png
# resized/saved 002595.png
# resized/saved 003423.png
# resized/saved 000282.png
# resized/saved 001290.png
# resized/saved 000292.png
# resized/saved 000012.png
# resized/saved 003223.png
# resized/saved 002524.png
# resized/saved 002696.png
# resized/saved 002346.png
# resized/saved 000289.png
# resized/saved 002668.png
# resized/saved 003284.png
# resized/saved 000579.png
# resized/saved 001595.png
# resized/saved 000283.png
# resized/saved 003131.png
# resized/saved 003595.png
# resized/saved 001396.png
# resized/saved 003811.png
# resized/saved 000850.png
# resized/saved 002844.png
# resized/saved 003481.png
# resized/saved 003472.png
# resized/saved 003572.png
# resized/saved 004103.png
# resized/saved 003081.png
# resized/saved 003945.png
# resized/saved 003403.png
# resized/saved 003113.png
# resized/saved 000252.png
# resized/saved 000740.png
# resized/saved 000498.png
# resized/saved 000356.png
# resized/saved 003954.png
# resized/saved 000034.png
# resized/saved 003404.png
# resized/saved 003428.png
# resized/saved 002179.png
# resized/saved 003712.png
# resized/saved 003032.png
# resized/saved 003212.png
# resized/saved 002649.png
# resized/saved 002350.png
# resized/saved 004097.png
# resized/saved 000487.png
# resized/saved 000150.png
# resized/saved 000213.png
# resized/saved 002986.png
# resized/saved 003492.png
# resized/saved 002898.png
# resized/saved 003722.png
# resized/saved 003729.png
# resized/saved 000184.png
# resized/saved 002355.png
# resized/saved 002530.png
# resized/saved 003846.png
# resized/saved 003303.png
# resized/saved 000293.png
# resized/saved 000495.png
# resized/saved 003241.png
# resized/saved 003121.png
# resized/saved 002771.png
# resized/saved 003501.png
# resized/saved 002503.png
# resized/saved 003188.png
# resized/saved 002523.png
# resized/saved 003242.png
# resized/saved 003927.png
# resized/saved 001029.png
# resized/saved 000004.png
# resized/saved 002584.png
# resized/saved 002514.png
# resized/saved 003101.png
# resized/saved 000473.png
# resized/saved 000006.png
# resized/saved 002462.png
# resized/saved 000472.png
# resized/saved 000139.png
# resized/saved 003075.png
# resized/saved 002808.png
# resized/saved 002886.png
# resized/saved 003027.png
# resized/saved 003057.png
# resized/saved 002814.png
# resized/saved 003401.png
# resized/saved 000145.png
# resized/saved 002439.png
# resized/saved 000153.png
# resized/saved 000273.png
# resized/saved 000746.png
# resized/saved 003230.png
# resized/saved 002698.png
# resized/saved 000548.png
# resized/saved 002472.png
# resized/saved 000223.png
# resized/saved 003159.png
# resized/saved 003268.png
# resized/saved 002653.png
# resized/saved 003536.png
# resized/saved 002666.png
# resized/saved 002906.png
# resized/saved 002427.png
# resized/saved 002400.png
# resized/saved 002677.png
# resized/saved 000792.png
# resized/saved 003944.png
# resized/saved 003042.png
# resized/saved 004108.png
# resized/saved 003160.png
# resized/saved 004022.png
# resized/saved 002416.png
# resized/saved 000114.png
# resized/saved 002739.png
# resized/saved 003537.png
# resized/saved 003680.png
# resized/saved 000475.png
# resized/saved 001653.png
# resized/saved 001625.png
# resized/saved 003112.png
# resized/saved 000021.png
# resized/saved 002706.png
# resized/saved 000509.png
# resized/saved 000275.png
# resized/saved 000564.png
# resized/saved 003713.png
# resized/saved 002950.png
# resized/saved 004011.png
# resized/saved 002688.png
# resized/saved 000939.png
# resized/saved 000111.png
# resized/saved 003052.png
# resized/saved 002608.png
# resized/saved 000449.png
# resized/saved 002761.png
# resized/saved 000795.png
# resized/saved 003137.png
# resized/saved 002353.png
# resized/saved 003245.png
# resized/saved 000592.png
# resized/saved 002398.png
# resized/saved 002263.png
# resized/saved 003206.png
# resized/saved 003326.png
# resized/saved 003322.png
# resized/saved 000745.png
# resized/saved 002422.png
# resized/saved 002258.png
# resized/saved 003109.png
# resized/saved 002537.png
# resized/saved 002490.png
# resized/saved 000758.png
# resized/saved 003169.png
# resized/saved 004099.png
# resized/saved 000734.png
# resized/saved 001907.png
# resized/saved 000011.png
# resized/saved 002492.png
# resized/saved 003275.png
# resized/saved 000789.png
# resized/saved 003226.png
# resized/saved 004105.png
# resized/saved 003759.png
# resized/saved 003544.png
# resized/saved 000018.png
# resized/saved 003694.png
# resized/saved 000730.png
# resized/saved 003857.png
# resized/saved 003685.png
# resized/saved 003119.png
# resized/saved 003009.png
# resized/saved 003760.png
# resized/saved 001864.png
# resized/saved 003714.png
# resized/saved 003751.png
# resized/saved 003681.png
# resized/saved 003375.png
# resized/saved 002426.png
# resized/saved 000233.png
# resized/saved 004060.png
# resized/saved 002923.png
# resized/saved 002621.png
# resized/saved 002510.png
# resized/saved 003355.png
# resized/saved 003142.png
# resized/saved 000199.png
# resized/saved 003707.png
# resized/saved 002407.png
# resized/saved 000791.png
# resized/saved 002932.png
# resized/saved 000133.png
# resized/saved 003203.png
# resized/saved 001737.png
# resized/saved 002919.png
# resized/saved 000481.png
# resized/saved 000477.png
# resized/saved 003304.png
# resized/saved 003420.png
# resized/saved 001860.png
# resized/saved 000269.png
# resized/saved 003276.png
# resized/saved 003271.png
# resized/saved 001878.png
# resized/saved 003256.png
# resized/saved 002733.png
# resized/saved 001900.png
# resized/saved 003559.png
# resized/saved 000707.png
# resized/saved 000732.png
# resized/saved 000126.png
# resized/saved 000483.png
# resized/saved 003756.png
# resized/saved 003289.png
# resized/saved 003600.png
# resized/saved 000274.png
# resized/saved 000108.png
# resized/saved 000276.png
# resized/saved 002034.png
# resized/saved 003667.png
# resized/saved 000711.png
# resized/saved 000452.png
# resized/saved 003691.png
# resized/saved 003551.png
# resized/saved 003747.png
# resized/saved 002605.png
# resized/saved 003474.png
# resized/saved 003406.png
# resized/saved 003529.png
# resized/saved 004160.png
# resized/saved 000777.png
# resized/saved 001866.png
# resized/saved 002433.png
# resized/saved 000190.png
# resized/saved 000484.png
# resized/saved 000257.png
# resized/saved 000932.png
# resized/saved 002599.png
# resized/saved 003506.png
# resized/saved 002663.png
# resized/saved 004076.png
# resized/saved 002613.png
# resized/saved 003727.png
# resized/saved 000748.png
# resized/saved 001627.png
# resized/saved 000800.png
# resized/saved 003254.png
# resized/saved 002683.png
# resized/saved 003034.png
# resized/saved 000680.png
# resized/saved 000209.png
# resized/saved 003071.png
# resized/saved 003585.png
# resized/saved 003294.png
# resized/saved 000206.png
# resized/saved 003665.png
# resized/saved 002454.png
# resized/saved 000699.png
# resized/saved 003542.png
# resized/saved 003150.png
# resized/saved 000566.png
# resized/saved 003881.png
# resized/saved 002450.png
# resized/saved 001624.png
# resized/saved 002689.png
# resized/saved 001195.png
# resized/saved 003085.png
# resized/saved 000198.png
# resized/saved 002651.png
# resized/saved 003750.png
# resized/saved 003580.png
# resized/saved 000853.png
# resized/saved 002568.png
# resized/saved 000307.png
# resized/saved 003073.png
# resized/saved 002410.png
# resized/saved 003546.png
# resized/saved 000026.png
# resized/saved 003622.png
# resized/saved 003248.png
# resized/saved 003874.png
# resized/saved 003059.png
# resized/saved 003348.png
# resized/saved 000506.png
# resized/saved 000174.png
# resized/saved 002442.png
# resized/saved 001656.png
# resized/saved 003431.png
# resized/saved 003743.png
# resized/saved 002295.png
# resized/saved 002415.png
# resized/saved 002607.png
# resized/saved 000852.png
# resized/saved 002317.png
# resized/saved 001912.png
# resized/saved 000017.png
# resized/saved 002391.png
# resized/saved 000845.png
# resized/saved 000839.png
# resized/saved 002272.png
# resized/saved 003095.png
# resized/saved 002769.png
# resized/saved 002408.png
# resized/saved 002516.png
# resized/saved 001820.png
# resized/saved 002432.png
# resized/saved 003111.png
# resized/saved 003662.png
# resized/saved 002652.png
# resized/saved 003636.png
# resized/saved 003692.png
# resized/saved 002726.png
# resized/saved 003981.png
# resized/saved 003100.png
# resized/saved 000540.png
# resized/saved 003658.png
# resized/saved 000238.png
# resized/saved 002765.png
# resized/saved 004166.png
# resized/saved 003097.png
# resized/saved 000941.png
# resized/saved 003335.png
# resized/saved 003668.png
# resized/saved 003684.png
# resized/saved 004172.png
# resized/saved 002047.png
# resized/saved 000945.png
# resized/saved 003056.png
# resized/saved 002738.png
# resized/saved 003554.png
# resized/saved 000722.png
# resized/saved 002392.png
# resized/saved 002971.png
# resized/saved 003060.png
# resized/saved 002968.png
# resized/saved 000744.png
# resized/saved 003353.png
# resized/saved 002369.png
# resized/saved 003061.png
# resized/saved 002339.png
# resized/saved 002871.png
# resized/saved 001908.png
# resized/saved 002829.png
# resized/saved 001658.png
# resized/saved 003677.png
# resized/saved 004072.png
# resized/saved 003863.png
# resized/saved 003260.png
# resized/saved 003132.png
# resized/saved 000526.png
# resized/saved 002833.png
# resized/saved 003737.png
# resized/saved 003118.png
# resized/saved 004002.png
# resized/saved 003376.png
# resized/saved 003414.png
# resized/saved 000008.png
# resized/saved 004014.png
# resized/saved 003114.png
# resized/saved 000854.png
# resized/saved 003498.png
# resized/saved 000940.png
# resized/saved 003087.png
# resized/saved 002676.png
# resized/saved 003328.png
# resized/saved 002927.png
# resized/saved 003880.png
# resized/saved 001857.png
# resized/saved 001861.png
# resized/saved 000672.png
# resized/saved 002796.png
# resized/saved 001847.png
# resized/saved 003066.png
# resized/saved 002501.png
# resized/saved 000300.png
# resized/saved 003238.png
# resized/saved 003647.png
# resized/saved 003511.png
# resized/saved 003593.png
# resized/saved 003710.png
# resized/saved 000345.png
# resized/saved 003329.png
# resized/saved 003590.png
# resized/saved 002434.png
# resized/saved 003748.png
# resized/saved 002316.png
# resized/saved 003897.png
# resized/saved 000681.png
# resized/saved 003300.png
# resized/saved 003324.png
# resized/saved 003054.png
# resized/saved 003594.png
# resized/saved 003487.png
# resized/saved 002571.png
# resized/saved 000501.png
# resized/saved 002393.png
# resized/saved 002489.png
# resized/saved 000251.png
# resized/saved 000124.png
# resized/saved 000731.png
# resized/saved 003173.png
# resized/saved 001916.png
# resized/saved 003400.png
# resized/saved 000144.png
# resized/saved 000240.png
# resized/saved 001902.png
# resized/saved 003735.png
# resized/saved 002575.png
# resized/saved 002728.png
# resized/saved 000762.png
# resized/saved 003187.png
# resized/saved 002566.png
# resized/saved 002481.png
# resized/saved 000155.png
# resized/saved 000822.png
# resized/saved 002362.png
# resized/saved 001637.png
# resized/saved 002384.png
# resized/saved 003064.png
# resized/saved 004086.png
# resized/saved 003660.png
# resized/saved 000230.png
# resized/saved 003117.png
# resized/saved 003136.png
# resized/saved 004206.png
# resized/saved 000287.png
# resized/saved 003295.png
# resized/saved 003373.png
# resized/saved 001879.png
# resized/saved 000192.png
# resized/saved 004209.png
# resized/saved 003967.png
# resized/saved 002381.png
# resized/saved 002695.png
# resized/saved 003591.png
# resized/saved 003029.png
# resized/saved 003318.png
# resized/saved 003629.png
# resized/saved 000301.png
# resized/saved 003425.png
# resized/saved 001620.png
# resized/saved 003369.png
# resized/saved 003409.png
# resized/saved 000033.png
# resized/saved 004038.png
# resized/saved 003728.png
# resized/saved 000755.png
# resized/saved 003764.png
# resized/saved 000268.png
# resized/saved 000738.png
# resized/saved 003253.png
# resized/saved 003512.png
# resized/saved 003503.png
# resized/saved 004187.png
# resized/saved 002255.png
# resized/saved 000245.png
# resized/saved 002839.png
# resized/saved 002168.png
# resized/saved 003134.png
# resized/saved 002451.png
# resized/saved 000491.png
# resized/saved 001342.png
# resized/saved 000764.png
# resized/saved 000835.png
# resized/saved 003221.png
# resized/saved 000743.png
# resized/saved 003754.png
# resized/saved 001899.png
# resized/saved 002614.png
# resized/saved 000814.png
# resized/saved 000780.png
# resized/saved 000752.png
# resized/saved 002536.png
# resized/saved 003655.png
# resized/saved 003105.png
# resized/saved 001891.png
# resized/saved 003776.png
# resized/saved 000486.png
# resized/saved 000803.png
# resized/saved 002717.png
# resized/saved 004221.png
# resized/saved 000843.png
# resized/saved 001931.png
# resized/saved 003745.png
# resized/saved 002834.png
# resized/saved 002379.png
# resized/saved 000439.png
# resized/saved 000272.png
# resized/saved 000737.png
# resized/saved 002885.png
# resized/saved 000254.png
# resized/saved 003563.png
# resized/saved 001914.png
# resized/saved 003469.png
# resized/saved 000249.png
# resized/saved 002939.png
# resized/saved 000149.png
# resized/saved 001973.png
# resized/saved 002548.png
# resized/saved 000824.png
# resized/saved 003193.png
# resized/saved 000197.png
# resized/saved 003124.png
# resized/saved 003198.png
# resized/saved 002509.png
# resized/saved 001186.png
# resized/saved 003170.png
# resized/saved 000025.png
# resized/saved 001623.png
# resized/saved 003495.png
# resized/saved 003217.png
# resized/saved 000834.png
# resized/saved 003079.png
# resized/saved 000388.png
# resized/saved 000577.png
# resized/saved 002669.png
# resized/saved 002626.png
# resized/saved 000414.png
# resized/saved 003108.png
# resized/saved 003251.png
# resized/saved 002403.png
# resized/saved 002475.png
# resized/saved 000195.png
# resized/saved 002333.png
# resized/saved 000729.png
# resized/saved 003810.png
# resized/saved 003130.png
# resized/saved 000510.png
# resized/saved 000278.png
# resized/saved 003558.png
# resized/saved 000492.png
# resized/saved 002413.png
# resized/saved 003033.png
# resized/saved 000364.png
# resized/saved 003288.png
# resized/saved 004046.png
# resized/saved 003638.png
# resized/saved 002306.png
# resized/saved 000736.png
# resized/saved 003618.png
# resized/saved 003464.png
# resized/saved 003588.png
# resized/saved 003505.png
# resized/saved 002513.png
# resized/saved 003447.png
# resized/saved 002375.png
# resized/saved 003144.png
# resized/saved 002479.png
# resized/saved 002093.png
# resized/saved 002328.png
# resized/saved 003161.png
# resized/saved 000125.png
# resized/saved 003693.png
# resized/saved 000461.png
# resized/saved 000614.png
# resized/saved 002539.png
# resized/saved 000280.png
# resized/saved 003615.png
# resized/saved 000232.png
# resized/saved 001630.png
# resized/saved 000785.png
# resized/saved 000259.png
# resized/saved 000709.png
# resized/saved 004220.png
# resized/saved 000435.png
# resized/saved 000262.png
# resized/saved 003125.png
# resized/saved 000217.png
# resized/saved 001926.png
# resized/saved 001966.png
# resized/saved 000418.png
# resized/saved 000279.png
# resized/saved 000942.png
# resized/saved 000635.png
# resized/saved 003739.png
# resized/saved 003220.png
# resized/saved 002564.png
# resized/saved 000782.png
# resized/saved 002782.png
# resized/saved 003123.png
# resized/saved 002402.png
# resized/saved 003263.png
# resized/saved 003286.png
# resized/saved 003104.png
# resized/saved 002711.png
# resized/saved 002877.png
# resized/saved 000763.png
# resized/saved 002565.png
# resized/saved 002108.png
# resized/saved 002457.png
# resized/saved 004021.png
# resized/saved 000552.png
# resized/saved 000129.png
# resized/saved 002502.png
# resized/saved 002406.png
# resized/saved 003366.png
# resized/saved 003363.png
# resized/saved 000196.png
# resized/saved 000802.png
# resized/saved 002658.png
# resized/saved 002896.png
# resized/saved 002461.png
# resized/saved 001851.png
# resized/saved 002594.png
# resized/saved 000636.png
# resized/saved 002901.png
# resized/saved 000002.png
# resized/saved 002890.png
# resized/saved 000010.png
# resized/saved 002414.png
# resized/saved 000721.png
# resized/saved 002468.png
# resized/saved 003252.png
# resized/saved 000549.png
# resized/saved 002121.png
# resized/saved 003584.png
# resized/saved 002865.png
# resized/saved 003917.png
# resized/saved 003080.png
# resized/saved 003237.png
# resized/saved 004114.png
# resized/saved 002378.png
# resized/saved 002293.png
# resized/saved 003140.png
# resized/saved 003541.png
# resized/saved 001365.png
# resized/saved 000728.png
# resized/saved 000116.png
# resized/saved 000023.png
# resized/saved 003762.png
# resized/saved 002574.png
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-170-906cb95c4b1a> in <module>()
#       5     img = Image.open(path.join(pic_loc,pn)).resize((stim_pix, stim_pix))
#       6     pn = path.basename(pn)
# ----> 7     img.save(path.join(savedir,pn),'png')
#       8     print 'resized/saved %s' %(pn)
#
# //anaconda/lib/python2.7/site-packages/PIL/Image.pyc in save(self, fp, format, **params)
#    1437
#    1438         try:
# -> 1439             save_handler(self, fp, filename)
#    1440         finally:
#    1441             # do what we can to clean up
#
# //anaconda/lib/python2.7/site-packages/PIL/PngImagePlugin.pyc in _save(im, fp, filename, chunk, check)
#     570         chunk(fp, "iCCP", data)
#     571
# --> 572     ImageFile._save(im, _idat(fp, chunk), [("zip", (0,0)+im.size, 0, rawmode)])
#     573
#     574     chunk(fp, "IEND", "")
#
# //anaconda/lib/python2.7/site-packages/PIL/ImageFile.pyc in _save(im, fp, tile)
#     485             while 1:
#     486                 l, s, d = e.encode(bufsize)
# --> 487                 fp.write(d)
#     488                 if s:
#     489                     break
#
# //anaconda/lib/python2.7/site-packages/PIL/PngImagePlugin.pyc in write(self, data)
#     458         self.chunk = chunk
#     459     def write(self, data):
# --> 460         self.chunk(self.fp, "IDAT", data)
#     461
#     462 def _save(im, fp, filename, chunk=putchunk, check=0):
#
# //anaconda/lib/python2.7/site-packages/PIL/PngImagePlugin.pyc in putchunk(fp, cid, *data)
#     447
#     448     fp.write(o32(len(data)) + cid)
# --> 449     fp.write(data)
#     450     hi, lo = Image.core.crc32(data, Image.core.crc32(cid))
#     451     fp.write(o16(hi) + o16(lo))
#
# IOError: [Errno 28] No space left on device

# %% [markdown]
# #### create design matrices, image seqeuences, frame files
# The image sequence files show the sequence of images indicated by the design matrix. The actual sequence of image frames presented during the experiment is the frame file. These are kept separate because during the experiment we do things like cue presentation, flashing, etc., that will not enter into the analysis. So the image_sequence files are used for analysis, the frame_files are used for presentation.

# %%
savedir = train_param_dict['savedir']

##name of image sequence
def trn_image_sequence_name(savedir,run_set, run,filetype='.png'):
    return path.join(savedir,'trn_image_sequence_set_%0.2d_run_%0.2d.%s' %(run_set,run,filetype))


##name of experimental frame file
def trn_frame_name(savedir,run_set, run,filetype='.png'):
    return path.join(savedir,'train_frame_file_set_%0.2d_run_%0.2d.%s' %(run_set,run,filetype))

##this expands the image_sequence into a frame_file: will use simple flashing. assume 3frame/1.5s  = 2 Hz 
def training_frame_handler(img):
    if 'blank' not in img:
        return [img, path.basename(blank_screen_name), img]
    if 'blank' in img:
        return [img, img, img]

# %%
def print_list(a_list, list_filename):
    with open(list_filename, 'w') as ff: 
        for item in a_list:
            for frame in item:
                ff.write("%s\n" % frame)

# %%
RUNS, SETS, IMAGES, LOOPS, FADE_IN_FRAMES, ISI_LAM, FADE_OUT_FRAMES,TR = map(lambda x: train_param_dict[x], ['RUNS', 'REPS_PER_RUN', 'PICS', 'REPS_PER_PIC', 'FADE_IN_FRAMES', 'ISI_LAM', 'FADE_OUT_FRAMES','TR'])

# %%
for rr in range(RUNS):
    cur_stim_list = [[path.basename(blank_screen_name)]]+[[pic_names.pop()] for _ in range(IMAGES)]
    for ss in range(SETS):
        isq_name = trn_image_sequence_name(savedir,ss,rr,filetype='txt')
        f_name = trn_frame_name(savedir,ss,rr,filetype='txt')
        print '==%s' %(path.basename(fname))
        dm = make_design_matrix(IMAGES,LOOPS,blank_states=[FADE_IN_FRAMES,ISI_LAM,FADE_OUT_FRAMES],seconds_per_state=TR)
        one_run = fmri_experiment(dm,cur_stim_list,seconds_per_state=TR,vols_per_state = 1)
        image_sequence = one_run.build_frame_list()
        print_list(image_sequence, isq_name)
        frame_list = [training_frame_handler(img) for img in image_sequence]
        print_list(frame_list, f_name)
        print '\n'
# Out:
# ==test_run_37_set_01.txt
# length of experiment: 197 states and 295.500000 seconds = 4.925000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 202 states and 303.000000 seconds = 5.050000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 194 states and 291.000000 seconds = 4.850000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 198 states and 297.000000 seconds = 4.950000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 195 states and 292.500000 seconds = 4.875000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 191 states and 286.500000 seconds = 4.775000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 198 states and 297.000000 seconds = 4.950000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 204 states and 306.000000 seconds = 5.100000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 206 states and 309.000000 seconds = 5.150000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 201 states and 301.500000 seconds = 5.025000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 202 states and 303.000000 seconds = 5.050000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 195 states and 292.500000 seconds = 4.875000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 201 states and 301.500000 seconds = 5.025000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 191 states and 286.500000 seconds = 4.775000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 198 states and 297.000000 seconds = 4.950000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 206 states and 309.000000 seconds = 5.150000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 206 states and 309.000000 seconds = 5.150000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 194 states and 291.000000 seconds = 4.850000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 190 states and 285.000000 seconds = 4.750000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 202 states and 303.000000 seconds = 5.050000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 199 states and 298.500000 seconds = 4.975000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 201 states and 301.500000 seconds = 5.025000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 205 states and 307.500000 seconds = 5.125000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 192 states and 288.000000 seconds = 4.800000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 207 states and 310.500000 seconds = 5.175000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 188 states and 282.000000 seconds = 4.700000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 198 states and 297.000000 seconds = 4.950000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 199 states and 298.500000 seconds = 4.975000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 197 states and 295.500000 seconds = 4.925000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 204 states and 306.000000 seconds = 5.100000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 204 states and 306.000000 seconds = 5.100000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 194 states and 291.000000 seconds = 4.850000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 188 states and 282.000000 seconds = 4.700000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 199 states and 298.500000 seconds = 4.975000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 184 states and 276.000000 seconds = 4.600000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 202 states and 303.000000 seconds = 5.050000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 182 states and 273.000000 seconds = 4.550000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 196 states and 294.000000 seconds = 4.900000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 194 states and 291.000000 seconds = 4.850000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 192 states and 288.000000 seconds = 4.800000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 202 states and 303.000000 seconds = 5.050000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 208 states and 312.000000 seconds = 5.200000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 196 states and 294.000000 seconds = 4.900000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 194 states and 291.000000 seconds = 4.850000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 199 states and 298.500000 seconds = 4.975000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 206 states and 309.000000 seconds = 5.150000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 194 states and 291.000000 seconds = 4.850000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 197 states and 295.500000 seconds = 4.925000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 195 states and 292.500000 seconds = 4.875000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 198 states and 297.000000 seconds = 4.950000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 197 states and 295.500000 seconds = 4.925000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 203 states and 304.500000 seconds = 5.075000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 209 states and 313.500000 seconds = 5.225000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 197 states and 295.500000 seconds = 4.925000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 190 states and 285.000000 seconds = 4.750000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 210 states and 315.000000 seconds = 5.250000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 194 states and 291.000000 seconds = 4.850000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 201 states and 301.500000 seconds = 5.025000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 195 states and 292.500000 seconds = 4.875000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 194 states and 291.000000 seconds = 4.850000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 193 states and 289.500000 seconds = 4.825000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 207 states and 310.500000 seconds = 5.175000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 198 states and 297.000000 seconds = 4.950000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 196 states and 294.000000 seconds = 4.900000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 205 states and 307.500000 seconds = 5.125000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 202 states and 303.000000 seconds = 5.050000 mintues
#
#
# ==test_run_37_set_01.txt
# length of experiment: 194 states and 291.000000 seconds = 4.850000 mintues

# %% [markdown]
# ### Create imagery runs

# %% [markdown]
# #### imagery set parameters

# %%
targ_param_dict = dict(train_param_dict)

targ_param_dict['savedir'] = '/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/'

targ_param_dict['TR'] = 3. ##not really, TR is still 1.5, but exp. is designed in 3s chunks, so.

##image parameters
targ_param_dict['PICS'] = 8 ##the number of images per run

##timing parameters
targ_param_dict['REPS_PER_PIC'] = 4      ## number of times each image is shown in a run.
targ_param_dict['RUNS'] = 1              ## number of runs
targ_param_dict['REPS_PER_RUN'] = 12  
targ_param_dict['ISI_LAM'] = 0.1

TR,frames_per_tr,isi = targ_param_dict['TR'],targ_param_dict['FRAMES_PER_TR'],targ_param_dict['ISI_LAM']
targ_param_dict['TIME_PER_PIC'] = .5*TR+(TR*(1./frames_per_tr))+(1+isi)*TR  ##cue+showtime+isi


print 'IMAGERY PARAMETERS'
targ_param_dict=print_exp_info(targ_param_dict)
# Out:
# IMAGERY PARAMETERS
# pixels per deg. 34.751
# 8 unique images will be shown 4 times per run
# average run duration (min): 4.493
# total time across runs (min): 4.493
# we have a total of 53.920000 minutes = 0.898667 hours of scan time
# assuming non-overlapping images in each run, a total of 8 unique images shown
# given a TR of 3.000, movie frame rate should be (Hz): 0.333333

# %% [markdown]
# #### blank,cue,etc.

# %%
##isi screen
savedir = targ_param_dict['savedir']
blank_lum = targ_param_dict['isi_luminance']
stim_pix = targ_param_dict['STIMULUS_PIXELS']
blank_screen_name = path.join(savedir,'blank_screen_%0.3d.png' %(blank_lum)) 

blank_screen = make_a_blank(stim_pix,blank_lum,'L')
blank_screen.save(blank_screen_name)

# %%
##imagery screen

img_lum = blank_lum+4
img_screen = make_a_blank(stim_pix,img_lum,'L')
img_screen_name = 'img_screen.png'
img_screen.save(path.join(savedir,img_screen_name) )

# %%
##cue screen
cue_size = train_param_dict['CUE_SIZE']
cue_pos = train_param_dict['CUE_POS']

ready_message='O'
ready_screen=put_text(make_a_blank(stim_pix,blank_lum,'L'), message=ready_message,size=cue_size,position=cue_pos,fill=0)
ready_screen_name = path.join(savedir,'targ_ready_screen.png')
ready_screen.save(ready_screen_name)

for cue in string.ascii_uppercase[:targ_param_dict['PICS']]:
    cue_screen = put_text(make_a_blank(stim_pix, blank_lum, 'L'), message=cue, size=cue_size, position=cue_pos,fill=0)
    cue_screen.save(path.join(savedir, 'cue_%s.png' % (cue)))

# %%
##name of image sequence
def targ_image_sequence_name(savedir, run_rep, run, filetype='.png'):
    return path.join(savedir,'targ_image_sequence_set_%0.2d_run_%0.2d.%s' %(run_rep,run,filetype))


##name of experimental frame file
def targ_frame_name(savedir,run_rep,run,filetype='.png'):
    return path.join(savedir,'targ_frame_file_set_%0.2d_run_%0.2d.%s' %(run_rep,run,filetype))

##this expands the image_sequence into a frame_file: will use simple flashing. assume 3frame/1.5s  = 2 Hz 
def targ_frame_handler(img, state):
    if 'blank' not in img:
        img_id = img[-4]
        cue = 'cue_%s' %(img_id)
        if state == 'pcp':
            return [path.basename(ready_screen_name), cue, path.basename(ready_screen_name), img, img, img]
        elif state=='img':
            return [path.basename(ready_screen_name), cue, path.basename(ready_screen_name), img_screen_name, img_screen_name, img_screen_name]
    if 'blank' in img:
        return [img]

# %%
targ_pic_names = glob('/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/*768_*.png')

# %%
targ_pic_names
# Out:
# ['/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/01_candle_768_A.png',
#  '/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/02_grape_juice_768_B.png',
#  '/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/03_cheeseburger_768_C.png',
#  '/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/05_peaches_768_D.png',
#  '/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/man_horse_768_E.png',
#  '/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/man_with_crow_768_F.png',
#  '/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/penelope_768_G.png',
#  '/Users/tnaselar/Data/Presentation/natural_scenes_imagery_summer_2016/imagery_targets/three_grecian_women_768_H.png']

# %%
RUNS, SETS, IMAGES, LOOPS, FADE_IN_FRAMES, ISI_LAM, FADE_OUT_FRAMES,TR = map(lambda x: targ_param_dict[x], ['RUNS', 'REPS_PER_RUN', 'PICS', 'REPS_PER_PIC', 'FADE_IN_FRAMES', 'ISI_LAM', 'FADE_OUT_FRAMES','TR'])

# %%
for rr in range(RUNS):
    cur_stim_list = [[path.basename(blank_screen_name)]]+[[targ_pic_names.pop()] for _ in range(IMAGES)]
#     for ss in range(SETS):
#         isq_name = targ_image_sequence_name(savedir,ss,rr,filetype='txt')
#         f_name = targ_frame_name(savedir,ss,rr,filetype='txt')
#         print '==%s' %(path.basename(fname))
#         dm = make_design_matrix(IMAGES,LOOPS,blank_states=[FADE_IN_FRAMES,ISI_LAM,FADE_OUT_FRAMES],seconds_per_state=TR)
#         one_run = fmri_experiment(dm,cur_stim_list,seconds_per_state=TR,vols_per_state = 1)
#         image_sequence = one_run.build_frame_list()
#         print_list(image_sequence, isq_name)
#         frame_list = [targ_frame_handler(img) for img in image_sequence]
#         print_list(frame_list, f_name)
#         print '\n'
